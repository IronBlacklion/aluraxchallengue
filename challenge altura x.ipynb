# %%
def ventas_por_categoria(df, nombre):
      conteo = df["Categoría del Producto"].value_counts()
          plt.pie(conteo, labels=conteo.index, autopct="%1.1f%%")
              plt.title(f"Ventas por Categoría - {nombre}")
                  plt.show()

                  ventas_por_categoria(tienda1, "Tienda 1")
                  ventas_por_categoria(tienda2, "Tienda 2")
                  ventas_por_categoria(tienda3, "Tienda 3")
                  ventas_por_categoria(tienda4, "Tienda 4")

# %%
ingresos = {
      "Tienda": ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"],
          "Ingreso Total": [
                  tienda1["Precio"].sum(),
                          tienda2["Precio"].sum(),
                                  tienda3["Precio"].sum(),
                                          tienda4["Precio"].sum()
                                              ]
                                              }

                                              df_ingresos = pd.DataFrame(ingresos)
                                              sns.barplot(x="Tienda", y="Ingreso Total", data=df_ingresos)
                                              plt.title("Ingresos Totales por Tienda")
                                              plt.show()
}

# %%
satisfaccion = {
      "Tienda": ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"],
          "Satisfacción Promedio": [
                  tienda1["Satisfacción"].mean(),
                          tienda2["Satisfacción"].mean(),
                                  tienda3["Satisfacción"].mean(),
                                          tienda4["Satisfacción"].mean()
                                              ]
                                              }

                                              df_satisfaccion = pd.DataFrame(satisfaccion)
                                              sns.barplot(x="Satisfacción Promedio", y="Tienda", data=df_satisfaccion)
                                              plt.title("Satisfacción Promedio por Tienda")
                                              plt.show()
}

# %%
from IPython.display import Markdown

Markdown("""
### 📌 Recomendación Final

Tras analizar los ingresos, las categorías más vendidas y la satisfacción del cliente, se recomienda **cerrar la Tienda 4**, ya que presenta el menor ingreso total y una satisfacción por debajo del promedio.

Este análisis puede servir como base para decisiones estratégicas futuras del Sr. Juan.
""")

# %%
# 1. Importar librerías
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 2. Cargar datos desde URLs públicas
url1 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda1 = pd.read_csv(url1)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)
